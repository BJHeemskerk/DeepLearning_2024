# %% [markdown]
# <a href="https://colab.research.google.com/github/BJHeemskerk/DeepLearning_2024/blob/jesse/Portfolio_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Voorspellen van huisprijzen**
#
# |Teamleden|Kaggle Username|GitHub Username|
# |--|--|--|
# |Nima Ghafar|NimaGhafar|NimaGhafar|
# |Busse Heemskerk|bussejheemskerk|BJHeemskerk|
# |Henry Lau|||
# |Jesse van Leeuwen|22096337|22096337|
#
# -- Opdrachtomschrijving --
#
# ## Inhoudsopgave
# 1. [H1: Importeren en inladen](#h1)
# 2. [H2: EDA](#h2)
# 3. [H3: Fully Connected Neural Network](#h3)
#
# ## H1: Importeren en inladen <a name='h1'></a>
# Eerst zullen de verschillende gebruikte libaries worden geimporteerd.

# %%
# Importeren van veel gebruikte libaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from PIL import Image
import datetime

# Importeren libaries voor aanpassen/behandelen features
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Importeren DL libaries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# Nu zal de data worden ingeladen. Om hiermee te beginnen zullen de csv bestanden worden ingeladen.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/DeepLearning_2024/Opdracht 1')

# %%
# Inladen van csv bestanden
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# Tonen van de data
display(train_data.head(), test_data.head())
# Out:
#    House ID  Bedrooms  Bathrooms  Area  Latitude  Longitude   Price
# 0         1         4        4.0  4053   33.6968  -111.8892  869500
# 1         2         4        3.0  3343   34.8280  -119.0349  865200
# 2         3         3        4.0  3923   33.7669  -111.9182  889000
# 3         4         5        5.0  4022   33.7752  -111.7791  910000
# 4         5         3        4.0  4116   33.7669  -111.9182  971226
#    House ID  Bedrooms  Bathrooms  Area  Latitude  Longitude
# 0       501         3        2.0  2330   35.6406  -120.7003
# 1       502         3        2.5  1339   35.6406  -120.7003
# 2       503         3        2.0  1472   35.6406  -120.7003
# 3       504         4        4.0  2681   35.6406  -120.7003
# 4       505         3        2.5  1935   33.8085  -117.9228

# %% [markdown]
# In de volgende code cel wordt de data van elke afbeelding in de train en de test map opgehaald.

# %%
# Aanmaken van te vullen lijsten
file_paths_tr = []
imgdata_tr = []
file_paths_te = []
imgdata_te = []

# Opzetten directories
directories = ["Train", "Test"]

# Ophalen van de bestanden
# Loopen over directories
for directory in directories:
    directory_path = os.path.join('/content/drive/My Drive/Colab Notebooks/DeepLearning_2024/Opdracht 1', directory)
    # Loopen over alle bestanden
    for file in os.listdir(directory_path):
        # Alleen checken van .jpg bestanden
        if file.endswith(".jpg"):
            # Aanmaken van pad naar het bestand.
            file_path = os.path.join(directory_path, file)

            # Openen van de afbeelding en omzetten naar np.array
            img = Image.open(file_path)
            img_array = np.array(img)

            # Vullen van juiste lijsten op basis van ID
            if int(file.split('.')[0]) > 500:  # We halen de ID uit de bestandsnaam
                file_paths_te.append(file_path)
                imgdata_te.append(img_array)
            else:
                file_paths_tr.append(file_path)
                imgdata_tr.append(img_array)

# %% [markdown]
# Nu alle data in lijsten is gezet kunnen er dataframes worden aangemaakt met de data van de afbeeldingen. Door de grootte van de arrays kan dit even duren.

# %%
# Initieren van het dataframe
train_images = pd.DataFrame(columns=["House ID", "FilePath", "ImgData"])
test_images = pd.DataFrame(columns=["House ID", "FilePath", "ImgData"])

# Aanvullen train dataset
train_images["House ID"] = train_data["House ID"]
train_images["FilePath"] = file_paths_tr
train_images["ImgData"] = imgdata_tr

# Aanvullen test dataset
test_images["House ID"] = test_data["House ID"]
test_images["FilePath"] = file_paths_te
test_images["ImgData"] = imgdata_te

# Tonen van de dataframes
display(train_images.head(), test_images.head())
# Out:
#    House ID                                           FilePath  \
# 0         1  /content/drive/My Drive/Colab Notebooks/DeepLe...
# 1         2  /content/drive/My Drive/Colab Notebooks/DeepLe...
# 2         3  /content/drive/My Drive/Colab Notebooks/DeepLe...
# 3         4  /content/drive/My Drive/Colab Notebooks/DeepLe...
# 4         5  /content/drive/My Drive/Colab Notebooks/DeepLe...
#
#                                              ImgData
# 0  [[[166, 122, 73], [172, 128, 79], [168, 124, 7...
# 1  [[[234, 234, 234], [233, 233, 233], [231, 231,...
# 2  [[[156, 126, 100], [164, 137, 110], [181, 154,...
# 3  [[[187, 149, 64], [187, 149, 64], [186, 148, 6...
# 4  [[[185, 157, 94], [184, 156, 93], [183, 155, 9...
#    House ID                                           FilePath  \
# 0       501  /content/drive/My Drive/Colab Notebooks/DeepLe...
# 1       502  /content/drive/My Drive/Colab Notebooks/DeepLe...
# 2       503  /content/drive/My Drive/Colab Notebooks/DeepLe...
# 3       504  /content/drive/My Drive/Colab Notebooks/DeepLe...
# 4       505  /content/drive/My Drive/Colab Notebooks/DeepLe...
#
#                                              ImgData
# 0  [[[250, 250, 250], [251, 251, 251], [245, 245,...
# 1  [[[196, 186, 177], [194, 184, 175], [205, 195,...
# 2  [[[222, 205, 185], [229, 212, 192], [221, 204,...
# 3  [[[255, 253, 214], [255, 253, 214], [254, 252,...
# 4  [[[22, 20, 21], [36, 34, 35], [36, 34, 35], [3...

# %% [markdown]
# Vervolgens zullen de dataframes worden getest door de afbeeldingen te tonen.

# %%
# Ophalen van pad naar afbeelding
image_path = train_images["FilePath"][0]

# Openen afbeelding
img = Image.open(image_path)

# Omzetten afbeelding naar np.array
img_array = np.array(img)

# Tonen van de afbeelding
plt.imshow(img)
plt.show()

# Opnieuw tonen van de afbeelding via DF
plt.imshow(train_images["ImgData"][0])
plt.show()

# %% [markdown]
# ## H2: EDA <a name='h2'></a>

# %% [markdown]
# - [ ] Voer een Exploratieve Data Analyse (EDA) uit:
#     - [ ] Lees de afbeeldingen in en toon enkele afbeeldingen.
#     - [ ] Laad het metadatabestand en maak relevante visualisaties om de relaties tussen de targetvariabele en de andere variabelen te onderzoeken.
# - [ ] Beschrijf wat de belangrijkste bevindingen zijn van de EDA.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
import seaborn as sns

# Load the metadata
train_df = pd.read_csv(r'train.csv')
test_df = pd.read_csv(r'test.csv')

# Display the first few rows of the dataframe
display(train_df.head())
display(test_df.head())

# Read and display images
train_images_dir = r'Train'
test_images_dir = r'Test'

# Display some images from the train set
train_images = os.listdir(train_images_dir)
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = cv2.imread(os.path.join(train_images_dir, train_images[i]))
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')

# Display some images from the test set
if 'Price' not in train_df.columns:
    raise KeyError("Column 'target' does not exist in the dataframe.")
# Out:
#    House ID  Bedrooms  Bathrooms  Area  Latitude  Longitude   Price
# 0         1         4        4.0  4053   33.6968  -111.8892  869500
# 1         2         4        3.0  3343   34.8280  -119.0349  865200
# 2         3         3        4.0  3923   33.7669  -111.9182  889000
# 3         4         5        5.0  4022   33.7752  -111.7791  910000
# 4         5         3        4.0  4116   33.7669  -111.9182  971226
#    House ID  Bedrooms  Bathrooms  Area  Latitude  Longitude
# 0       501         3        2.0  2330   35.6406  -120.7003
# 1       502         3        2.5  1339   35.6406  -120.7003
# 2       503         3        2.0  1472   35.6406  -120.7003
# 3       504         4        4.0  2681   35.6406  -120.7003
# 4       505         3        2.5  1935   33.8085  -117.9228

# %%
# EDA on train dataframe
print("Train dataframe shape:", train_df.shape)

# Use describe() for summary statistics
print("Train dataframe summary statistics:")
display(train_df.describe(include='all'))

# Use info() for data types and missing values
print("Train dataframe info:")
display(train_df.info())

# EDA on test dataframe
print("Test dataframe shape:", test_df.shape)

# Use describe() for summary statistics
print("Test dataframe summary statistics:")
display(test_df.describe(include='all'))

# Use info() for data types and missing values
print("Test dataframe info:")
display(test_df.info())

# Visualize the distribution of the target variable in the train dataframe
plt.figure(figsize=(10, 6))
sns.histplot(train_df['Price'], kde=True)
plt.title('Distribution of Price in Train Data')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

sns.pairplot(train_df)
plt.show()
# Out:
# Train dataframe shape: (500, 7)
# Train dataframe summary statistics:
#          House ID    Bedrooms   Bathrooms        Area    Latitude   Longitude  \
# count  500.000000  500.000000  500.000000   500.00000  500.000000  500.000000
# mean   250.500000    3.350000    2.669500  2369.64600   35.128844 -116.469049
# std    144.481833    1.172283    1.017578  1208.18261    2.386173    6.554434
# min      1.000000    1.000000    1.000000   701.00000   32.631500 -122.368300
# 25%    125.750000    2.000000    2.000000  1440.00000   33.808200 -119.802500
# 50%    250.500000    3.000000    2.500000  2097.50000   33.920800 -117.609600
# 75%    375.250000    4.000000    3.000000  3104.50000   35.640600 -116.371300
# max    500.000000   10.000000    7.000000  9583.00000   47.791800  -87.885900
#
#               Price
# count  5.000000e+02
# mean   5.980218e+05
# std    5.240649e+05
# min    2.200000e+04
# 25%    2.350000e+05
# 50%    5.300000e+05
# 75%    7.490000e+05
# max    5.858000e+06
# Train dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   House ID   500 non-null    int64
#  1   Bedrooms   500 non-null    int64
#  2   Bathrooms  500 non-null    float64
#  3   Area       500 non-null    int64
#  4   Latitude   500 non-null    float64
#  5   Longitude  500 non-null    float64
#  6   Price      500 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 27.5 KB
# None
# Test dataframe shape: (35, 6)
# Test dataframe summary statistics:
#          House ID   Bedrooms  Bathrooms         Area   Latitude   Longitude
# count   35.000000  35.000000  35.000000    35.000000  35.000000   35.000000
# mean   518.000000   3.771429   2.600000  2297.171429  36.631043 -120.662114
# std     10.246951   0.910259   0.591608  1457.127886   1.837672    1.670038
# min    501.000000   2.000000   1.500000   987.000000  33.808500 -121.775800
# 25%    509.500000   3.000000   2.000000  1580.000000  34.724550 -121.775800
# 50%    518.000000   4.000000   2.500000  2012.000000  37.965800 -121.775800
# 75%    526.500000   4.000000   3.000000  2387.500000  37.965800 -119.311550
# max    535.000000   7.000000   4.000000  9536.000000  37.965800 -117.922800
# Test dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   House ID   35 non-null     int64
#  1   Bedrooms   35 non-null     int64
#  2   Bathrooms  35 non-null     float64
#  3   Area       35 non-null     int64
#  4   Latitude   35 non-null     float64
#  5   Longitude  35 non-null     float64
# dtypes: float64(3), int64(3)
# memory usage: 1.8 KB
# None

# %%
# Maak een heatmap met  cmap='RdYlGn' alleen op "Price" in de train dataframe en in volgorde van hoog naar laag
plt.figure(figsize=(10, 6))
sns.heatmap(train_df.corr()[['Price']].sort_values(by='Price', ascending=False), annot=True, cmap='RdYlGn')
plt.title('Correlation of Features with Price')
plt.show()

# Maak een heatmap met  cmap='RdYlGn' voor alle kolommen in de train dataframe en in volgorde van hoog naar laag

plt.figure(figsize=(10, 6))
sns.heatmap(train_df.corr(), annot=True, cmap='RdYlGn')
plt.title('Correlation of Features')
plt.show()

# %% [markdown]
# ## H3: Splitsen en scalen
#
# Voordat er neurale netwerken kunnen worden opgesteld, zal eerst nog de train_data dataset worden opgesplitst in een test en een validatie set.

# %%
# Aanmaken van de random_state SEED
SEED = 42

# Opslitsten van data in X en y
X = train_data.drop(['House ID', 'Price'], axis=1)
y = train_data['Price']

# Toepassen van train_test_split
X_train, X_test, y_train, y_test = train_test_split(
                                        X, y, test_size=0.1, random_state=SEED
                                       )

# %% [markdown]
# Vervolgens moet de data worden gescaled, dit zorgt ervoor dat het model betere verbanden kan leggen tussen de verschillende variabelen.

# %%
# Scalen van de gesplitste data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Scalen van de test_data
# Aanmaken lijst met nodige kolomnamen
kolomnamen = ["Bedrooms", "Bathrooms", "Area", "Latitude", "Longitude"]

# Scalen van de nodige kolommen
test_fe = test_data[kolomnamen]
sc_test_fe = scaler.fit_transform(test_fe)

# %% [markdown]
# **versie 1 van het model (fcnn-1)**

# %% [markdown]
# ## H3: Fully Connencted Neural Network <a name='h3'></a>
#
# Nu kan er worden begonnen met het opzetten van verschillende voorspellingen. Het eerste type voorspelling dat voor zal komen is een Fully Connected Neural Network. Dit netwerk bestaat uit de volgende lagen:
#
# **Input laag:**<br>
# De input laag van een neuraal netwerk bestaat uit een bepaald aantal neuronen. Het aantal neuronen moet gelijk zijn aan het aantal features dat in de dataset beschikbaar is. In onze datasets zijn er 5 features te vinden, dus heeft de input laag 5 neuronen.
#
# In alle hidden layers is gebruik gemaakt van een trial & error aanpak, waarmee er met verschillende hoeveelheden van neuronen en verschillende activatie functies is getest. Uiteindelijk kwamen hier de volgende aantallen en activaties uit:
#
# **Hidden Layer 1:**<br>
# - Neuronen: 128
# - Activatie: Rectified Linear Unit
#
# **Hidden Layer 2:**<br>
# - Neuronen: 64
# - Activatie: Rectified Linear Unit
#
# **Hidden Layer 3:**<br>
# - Neuronen: 64
# - Activatie: Rectified Linear Unit
#
# **Hidden Layer 4:**<br>
# - Neuronen: 16
# - Activatie: Rectified Linear Unit
#
# Voor de output laag geldt ongeveer hetzelfde als voor de input laag. Het aantal neuronen in de output laag hoort gelijk te zijn aan het aantal klassen die worden voorspeld bij classificatie. Bij regressie taken is er vaak maar 1 neuron in de output laag aanwezig, omdat er een eenvoudige numerieke voorspelling wordt gemaakt. In ons regressie probleem is deze waarde de huisprijs. Bij regressie is er ook sprake van de activatie functie 'linear', ookwel bekend als geen activatie.

# %% [markdown]
# Nu de data is gesplitst zal er een Fully Connected Neural Network worden opgebouwd.

# %%
# Aanmaken NN mbv Sequential API
fcnn = Sequential()

# Toevoegen input en eerste hidden layer
fcnn.add(Dense(128, input_shape=(5,), activation='relu'))

# Toevoegen andere hidden layers
fcnn.add(Dense(64, activation='relu'))
fcnn.add(Dense(64, activation='relu'))
fcnn.add(Dense(16, activation='relu'))

# Toevoegen van output layer
fcnn.add(Dense(1, activation='linear'))

# %% [markdown]
# Nadat alle lagen van het model zijn opgesteld, is het tijd om het model te compilen. Deze stap voegt enkele parameters toe aan het model:
# - De optimizer, een algoritme dat bepaalt op welke wijze het model leert tijdens het trainen.
# - De loss functie, een functie die aantoont hoe goed het model presteert op de gegevens.
# - De metric, een extra, optionele meetwaarde voor de prestatie van het model.
#
# Voor ons model is er gekozen voor de volgende parameters:
# - De Adam (Adaptive Moment estimator) optimizer
# - Mean Squared Error als loss
# - Mean Absolute Percentage Error als metric.
#
# De keuze voor de optimizer en de loss is gemaakt door een paar van de bekendste en meest gebruikte opties te nemen. Als metric is er gekozen voor de MAPE, omdat deze metric ook wordt gebruikt in de kaggle competitie.
#
# Daarnaast is er ook een module aangemaakt om het model eerder te kunnen stoppen, in het geval dat er niet veel meer veranderd aan de loss van de validatie data.

# %%
# Compilen van het model
fcnn.compile(
    optimizer=Adam(learning_rate=0.01),
    loss=tf.keras.losses.MeanSquaredError(),
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError()]
)

# Maken van een vroege stop module
early_stop = EarlyStopping(
    monitor='val_loss', patience=25, restore_best_weights=True
    )

# %% [markdown]
# Nu alles is aangemaakt kan het model worden getrained. Hierbij gebruiken we de trainings data, de validatie data, een gekozen aantal epochs, een batch size en een callback module. De epochs staan voor het aantal iteraties dat het model door zal gaan, door gebruik van de callback module is er gekozen om 5000 epochs uit te voeren. Zodra de loss op de validatie set voor 100 epochs niet genoeg veranderd zal het model automatisch stoppen en worden de parameters van de beste epoch hersteld. De batch size wijst op het aantal datapunten dat per epoch wordt gebruikt, bij ons is er gekozen voor een batch size van 16.

# %%
# Fitten van het model met de data
h_fcnn = fcnn.fit(
    X_train, y_train,
    batch_size=16,
    epochs=5000,
    validation_data=(X_test, y_test),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/5000
# 29/29 [==============================] - 3s 12ms/step - loss: 645573640192.0000 - mean_absolute_percentage_error: 99.6833 - val_loss: 485997576192.0000 - val_mean_absolute_percentage_error: 97.2431
# Epoch 2/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 507191853056.0000 - mean_absolute_percentage_error: 81.5362 - val_loss: 160342392832.0000 - val_mean_absolute_percentage_error: 93.4213
# Epoch 3/5000
# 29/29 [==============================] - 0s 4ms/step - loss: 235982831616.0000 - mean_absolute_percentage_error: 92.4192 - val_loss: 138653646848.0000 - val_mean_absolute_percentage_error: 66.0265
# Epoch 4/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 199880900608.0000 - mean_absolute_percentage_error: 74.7827 - val_loss: 121833324544.0000 - val_mean_absolute_percentage_error: 77.8521
# Epoch 5/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 186321715200.0000 - mean_absolute_percentage_error: 76.3874 - val_loss: 106855849984.0000 - val_mean_absolute_percentage_error: 65.5349
# Epoch 6/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 181870804992.0000 - mean_absolute_percentage_error: 71.9732 - val_loss: 103928774656.0000 - val_mean_absolute_percentage_error: 73.4711
# Epoch 7/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 179914899456.0000 - mean_absolute_percentage_error: 71.4196 - val_loss: 96923435008.0000 - val_mean_absolute_percentage_error: 63.1675
# Epoch 8/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 177672929280.0000 - mean_absolute_percentage_error: 78.0504 - val_loss: 96354443264.0000 - val_mean_absolute_percentage_error: 67.6827
# Epoch 9/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 176948740096.0000 - mean_absolute_percentage_error: 69.7097 - val_loss: 94898987008.0000 - val_mean_absolute_percentage_error: 66.3350
# Epoch 10/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 173144489984.0000 - mean_absolute_percentage_error: 70.6854 - val_loss: 94170300416.0000 - val_mean_absolute_percentage_error: 69.4423
# Epoch 11/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 172739657728.0000 - mean_absolute_percentage_error: 74.8520 - val_loss: 91930411008.0000 - val_mean_absolute_percentage_error: 62.2961
# Epoch 12/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 173913128960.0000 - mean_absolute_percentage_error: 68.3873 - val_loss: 93439328256.0000 - val_mean_absolute_percentage_error: 67.2153
# Epoch 13/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 170763337728.0000 - mean_absolute_percentage_error: 67.1667 - val_loss: 99928760320.0000 - val_mean_absolute_percentage_error: 69.4613
# Epoch 14/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 173408092160.0000 - mean_absolute_percentage_error: 71.3412 - val_loss: 91371479040.0000 - val_mean_absolute_percentage_error: 64.9063
# Epoch 15/5000
# 29/29 [==============================] - 0s 4ms/step - loss: 169970139136.0000 - mean_absolute_percentage_error: 69.2817 - val_loss: 94598881280.0000 - val_mean_absolute_percentage_error: 58.6884
# Epoch 16/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 167410794496.0000 - mean_absolute_percentage_error: 66.6613 - val_loss: 96869400576.0000 - val_mean_absolute_percentage_error: 69.2043
# Epoch 17/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 169212166144.0000 - mean_absolute_percentage_error: 67.6927 - val_loss: 90907312128.0000 - val_mean_absolute_percentage_error: 59.1590
# Epoch 18/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 165886984192.0000 - mean_absolute_percentage_error: 67.1908 - val_loss: 89174646784.0000 - val_mean_absolute_percentage_error: 55.8878
# Epoch 19/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 166933446656.0000 - mean_absolute_percentage_error: 64.5390 - val_loss: 94044971008.0000 - val_mean_absolute_percentage_error: 65.7543
# Epoch 20/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 164517134336.0000 - mean_absolute_percentage_error: 65.0977 - val_loss: 89952509952.0000 - val_mean_absolute_percentage_error: 54.5639
# Epoch 21/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 163102195712.0000 - mean_absolute_percentage_error: 57.3335 - val_loss: 111384010752.0000 - val_mean_absolute_percentage_error: 71.3852
# Epoch 22/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 177085169664.0000 - mean_absolute_percentage_error: 67.6553 - val_loss: 91232829440.0000 - val_mean_absolute_percentage_error: 59.3258
# Epoch 23/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 161812480000.0000 - mean_absolute_percentage_error: 59.5871 - val_loss: 95171379200.0000 - val_mean_absolute_percentage_error: 60.3872
# Epoch 24/5000
# 29/29 [==============================] - 0s 4ms/step - loss: 163288743936.0000 - mean_absolute_percentage_error: 59.7012 - val_loss: 89760456704.0000 - val_mean_absolute_percentage_error: 56.6747
# Epoch 25/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 159920668672.0000 - mean_absolute_percentage_error: 61.2438 - val_loss: 91169538048.0000 - val_mean_absolute_percentage_error: 54.2478
# Epoch 26/5000
# 29/29 [==============================] - 0s 8ms/step - loss: 160857407488.0000 - mean_absolute_percentage_error: 56.0349 - val_loss: 93142949888.0000 - val_mean_absolute_percentage_error: 55.1086
# Epoch 27/5000
# 29/29 [==============================] - 0s 7ms/step - loss: 161125122048.0000 - mean_absolute_percentage_error: 58.5329 - val_loss: 93948592128.0000 - val_mean_absolute_percentage_error: 64.1033
# Epoch 28/5000
# 29/29 [==============================] - 0s 7ms/step - loss: 159461179392.0000 - mean_absolute_percentage_error: 60.2495 - val_loss: 90283548672.0000 - val_mean_absolute_percentage_error: 55.0045
# Epoch 29/5000
# 29/29 [==============================] - 0s 7ms/step - loss: 157097672704.0000 - mean_absolute_percentage_error: 56.4410 - val_loss: 90282360832.0000 - val_mean_absolute_percentage_error: 53.5118
# Epoch 30/5000
# 29/29 [==============================] - 0s 8ms/step - loss: 161475002368.0000 - mean_absolute_percentage_error: 56.4589 - val_loss: 93514694656.0000 - val_mean_absolute_percentage_error: 55.3984
# Epoch 31/5000
# 29/29 [==============================] - 0s 8ms/step - loss: 156980363264.0000 - mean_absolute_percentage_error: 53.7888 - val_loss: 97270972416.0000 - val_mean_absolute_percentage_error: 59.1644
# Epoch 32/5000
# 29/29 [==============================] - 0s 7ms/step - loss: 159435816960.0000 - mean_absolute_percentage_error: 52.9943 - val_loss: 91058634752.0000 - val_mean_absolute_percentage_error: 53.3433
# Epoch 33/5000
# 29/29 [==============================] - 0s 7ms/step - loss: 156863053824.0000 - mean_absolute_percentage_error: 54.4681 - val_loss: 90916446208.0000 - val_mean_absolute_percentage_error: 51.8261
# Epoch 34/5000
# 29/29 [==============================] - 0s 7ms/step - loss: 156401729536.0000 - mean_absolute_percentage_error: 54.0257 - val_loss: 89928318976.0000 - val_mean_absolute_percentage_error: 53.2187
# Epoch 35/5000
# 29/29 [==============================] - 0s 7ms/step - loss: 157787258880.0000 - mean_absolute_percentage_error: 52.6407 - val_loss: 93258088448.0000 - val_mean_absolute_percentage_error: 51.1423
# Epoch 36/5000
# 29/29 [==============================] - 0s 7ms/step - loss: 156194832384.0000 - mean_absolute_percentage_error: 54.5401 - val_loss: 92217475072.0000 - val_mean_absolute_percentage_error: 58.7996
# Epoch 37/5000
# 29/29 [==============================] - 0s 7ms/step - loss: 156436414464.0000 - mean_absolute_percentage_error: 49.1546 - val_loss: 102663299072.0000 - val_mean_absolute_percentage_error: 66.6405
# Epoch 38/5000
# 29/29 [==============================] - 0s 7ms/step - loss: 159420088320.0000 - mean_absolute_percentage_error: 53.5144 - val_loss: 89196322816.0000 - val_mean_absolute_percentage_error: 53.6818
# Epoch 39/5000
# 29/29 [==============================] - 0s 7ms/step - loss: 161476919296.0000 - mean_absolute_percentage_error: 55.1632 - val_loss: 90986553344.0000 - val_mean_absolute_percentage_error: 55.5141
# Epoch 40/5000
# 29/29 [==============================] - 0s 8ms/step - loss: 158596382720.0000 - mean_absolute_percentage_error: 51.8409 - val_loss: 94708105216.0000 - val_mean_absolute_percentage_error: 56.9629
# Epoch 41/5000
# 29/29 [==============================] - 0s 8ms/step - loss: 155932147712.0000 - mean_absolute_percentage_error: 51.3123 - val_loss: 89893978112.0000 - val_mean_absolute_percentage_error: 55.7461
# Epoch 42/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 154952056832.0000 - mean_absolute_percentage_error: 48.7876 - val_loss: 91420540928.0000 - val_mean_absolute_percentage_error: 51.2538
# Epoch 43/5000
# 29/29 [==============================] - 0s 5ms/step - loss: 153956106240.0000 - mean_absolute_percentage_error: 52.7056 - val_loss: 93378535424.0000 - val_mean_absolute_percentage_error: 57.3728

# %% [markdown]
# Met het getrainde model kan er gekeken worden naar de loss van de train data en de validatie data. Op deze manier kan er in een enkele grafiek worden gezien of er sprake is van overfitting of andere problemen.

# %%
plt.plot(h_fcnn.history['loss'], label='Training loss')
plt.plot(h_fcnn.history['val_loss'], 'g', label='Validation loss')
plt.xlabel('Epoch #')
plt.ylabel('Loss (MAPE)')
plt.title('Loss grafiek voor FCNN-model')
plt.legend()
plt.show()

# %% [markdown]
# Zoals in de grafiek is te zien, is er sprake van geen van overfitting. Overfitting wordt namelijk aangeduid door het stijgen van de validatie loss.
#
# Nu het model is getrained en de loss is bekeken, kan de voorspelling worden geupload naar kaggle. Aan de hand van de voorspellingen kan er een csv bestand aangemaakt worden voor de kaggle competitie. Omdat deze bestanden vaker moeten worden aangemaakt en om de bestanden overzichtelijk en uniform te houden is hiervoor een functie aangemaakt.

# %%
model_save_path = '/content/drive/My Drive/Colab Notebooks/DeepLearning_2024/Opdracht 1/modelversies/fcnn_model_v1.h5'
fcnn.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.models import load_model


model_load_path = '/content/drive/My Drive/Colab Notebooks/DeepLearning_2024/Opdracht 1/modelversies/fcnn_model_v1.h5'


model = load_model(model_load_path)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               768
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 16)                1040
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 14241 (55.63 KB)
# Trainable params: 14241 (55.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # score verbeteren

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.27)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.10.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)

# %%
import optuna
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Laad je data hier
# Voorbeeld: train_data = pd.read_csv('train.csv')
# test_data = pd.read_csv('test.csv')

# Splits je data in features en target
X = train_data.drop(['House ID', 'Price'], axis=1).values
y = train_data['Price'].values

# Scalen van de data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Splits de data in train en test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.1, random_state=42)

def create_model(trial):
    # Bepaal de architectuur van het model met de trial suggest methoden
    model = Sequential()
    model.add(Dense(trial.suggest_int('input_neurons', 5, 128), activation='relu', input_shape=(X_train.shape[1],)))

    # Voeg dynamisch lagen toe
    n_layers = trial.suggest_int('n_layers', 1, 4)
    for i in range(n_layers):
        model.add(Dense(trial.suggest_int(f'n_units_l{i}', 5, 128), activation='relu'))

    model.add(Dense(1, activation='linear'))
    return model

def objective(trial):
    model = create_model(trial)

    # Kies hyperparameters
    lr = trial.suggest_float('lr', 1e-5, 1e-1, log=True)
    model.compile(loss='mean_squared_error',
                  optimizer=Adam(learning_rate=lr),
                  metrics=['mean_absolute_percentage_error'])

    early_stop = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

    model.fit(X_train, y_train, validation_data=(X_test, y_test),
              epochs=100, batch_size=16, callbacks=[early_stop], verbose=0)

    loss, mape = model.evaluate(X_test, y_test, verbose=0)
    return mape

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=200)

print('Beste trial:', study.best_trial.params)
# Out:
# [I 2024-03-06 17:52:20,178] A new study created in memory with name: no-name-9610b881-d5d6-49b1-85e3-1c082fd6f9bd
# [I 2024-03-06 17:52:46,168] Trial 0 finished with value: 99.3311996459961 and parameters: {'input_neurons': 100, 'n_layers': 3, 'n_units_l0': 104, 'n_units_l1': 30, 'n_units_l2': 47, 'lr': 3.8294502480943596e-05}. Best is trial 0 with value: 99.3311996459961.
# [I 2024-03-06 17:53:01,987] Trial 1 finished with value: 79.1481704711914 and parameters: {'input_neurons': 71, 'n_layers': 1, 'n_units_l0': 53, 'lr': 0.002360547323927169}. Best is trial 1 with value: 79.1481704711914.
# [I 2024-03-06 17:53:16,841] Trial 2 finished with value: 64.02296447753906 and parameters: {'input_neurons': 120, 'n_layers': 3, 'n_units_l0': 39, 'n_units_l1': 53, 'n_units_l2': 63, 'lr': 0.0014710485786897946}. Best is trial 2 with value: 64.02296447753906.
# [I 2024-03-06 17:53:38,342] Trial 3 finished with value: 81.17350769042969 and parameters: {'input_neurons': 83, 'n_layers': 2, 'n_units_l0': 54, 'n_units_l1': 98, 'lr': 0.0003722769679470013}. Best is trial 2 with value: 64.02296447753906.
# [I 2024-03-06 17:53:59,494] Trial 4 finished with value: 99.92324829101562 and parameters: {'input_neurons': 48, 'n_layers': 1, 'n_units_l0': 36, 'lr': 0.00010802531381432191}. Best is trial 2 with value: 64.02296447753906.
# [I 2024-03-06 17:54:12,385] Trial 5 finished with value: 64.00103759765625 and parameters: {'input_neurons': 108, 'n_layers': 1, 'n_units_l0': 103, 'lr': 0.007938473362355683}. Best is trial 5 with value: 64.00103759765625.
# [I 2024-03-06 17:54:33,798] Trial 6 finished with value: 71.51437377929688 and parameters: {'input_neurons': 44, 'n_layers': 3, 'n_units_l0': 26, 'n_units_l1': 126, 'n_units_l2': 20, 'lr': 0.0004559893030967282}. Best is trial 5 with value: 64.00103759765625.
# [I 2024-03-06 17:54:55,374] Trial 7 finished with value: 57.48468780517578 and parameters: {'input_neurons': 41, 'n_layers': 3, 'n_units_l0': 91, 'n_units_l1': 81, 'n_units_l2': 58, 'lr': 0.002728345920090252}. Best is trial 7 with value: 57.48468780517578.
# [I 2024-03-06 17:55:10,520] Trial 8 finished with value: 99.8408432006836 and parameters: {'input_neurons': 111, 'n_layers': 3, 'n_units_l0': 50, 'n_units_l1': 127, 'n_units_l2': 63, 'lr': 1.815991308066942e-05}. Best is trial 7 with value: 57.48468780517578.
# [I 2024-03-06 17:55:25,154] Trial 9 finished with value: 43.748985290527344 and parameters: {'input_neurons': 79, 'n_layers': 3, 'n_units_l0': 93, 'n_units_l1': 54, 'n_units_l2': 24, 'lr': 0.06048754864764701}. Best is trial 9 with value: 43.748985290527344.
# [I 2024-03-06 17:55:38,138] Trial 10 finished with value: 37.100685119628906 and parameters: {'input_neurons': 11, 'n_layers': 4, 'n_units_l0': 128, 'n_units_l1': 16, 'n_units_l2': 126, 'n_units_l3': 70, 'lr': 0.08401514673422818}. Best is trial 10 with value: 37.100685119628906.
# [I 2024-03-06 17:55:49,060] Trial 11 finished with value: 37.495765686035156 and parameters: {'input_neurons': 25, 'n_layers': 4, 'n_units_l0': 126, 'n_units_l1': 5, 'n_units_l2': 126, 'n_units_l3': 68, 'lr': 0.095593065974928}. Best is trial 10 with value: 37.100685119628906.
# [I 2024-03-06 17:55:57,193] Trial 12 finished with value: 45.10746765136719 and parameters: {'input_neurons': 6, 'n_layers': 4, 'n_units_l0': 127, 'n_units_l1': 6, 'n_units_l2': 124, 'n_units_l3': 71, 'lr': 0.09300324301358302}. Best is trial 10 with value: 37.100685119628906.
# [I 2024-03-06 17:56:08,471] Trial 13 finished with value: 61.064208984375 and parameters: {'input_neurons': 9, 'n_layers': 4, 'n_units_l0': 124, 'n_units_l1': 5, 'n_units_l2': 120, 'n_units_l3': 65, 'lr': 0.020449863632016257}. Best is trial 10 with value: 37.100685119628906.
# [I 2024-03-06 17:56:24,636] Trial 14 finished with value: 36.588836669921875 and parameters: {'input_neurons': 23, 'n_layers': 4, 'n_units_l0': 76, 'n_units_l1': 29, 'n_units_l2': 100, 'n_units_l3': 112, 'lr': 0.02063695239209734}. Best is trial 14 with value: 36.588836669921875.
# [I 2024-03-06 17:56:46,131] Trial 15 finished with value: 36.05207443237305 and parameters: {'input_neurons': 26, 'n_layers': 4, 'n_units_l0': 5, 'n_units_l1': 30, 'n_units_l2': 95, 'n_units_l3': 125, 'lr': 0.01606833414985454}. Best is trial 15 with value: 36.05207443237305.
# [I 2024-03-06 17:57:07,433] Trial 16 finished with value: 55.623722076416016 and parameters: {'input_neurons': 30, 'n_layers': 2, 'n_units_l0': 75, 'n_units_l1': 33, 'lr': 0.01185463100423403}. Best is trial 15 with value: 36.05207443237305.
# [I 2024-03-06 17:57:24,100] Trial 17 finished with value: 29.427295684814453 and parameters: {'input_neurons': 59, 'n_layers': 4, 'n_units_l0': 9, 'n_units_l1': 40, 'n_units_l2': 94, 'n_units_l3': 126, 'lr': 0.026577327643502534}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 17:57:35,412] Trial 18 finished with value: 60.02763748168945 and parameters: {'input_neurons': 61, 'n_layers': 4, 'n_units_l0': 7, 'n_units_l1': 49, 'n_units_l2': 89, 'n_units_l3': 128, 'lr': 0.006587727637671091}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 17:57:46,778] Trial 19 finished with value: 62.479827880859375 and parameters: {'input_neurons': 58, 'n_layers': 2, 'n_units_l0': 6, 'n_units_l1': 73, 'lr': 0.029760405020471257}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 17:58:08,826] Trial 20 finished with value: 59.506492614746094 and parameters: {'input_neurons': 85, 'n_layers': 4, 'n_units_l0': 20, 'n_units_l1': 43, 'n_units_l2': 90, 'n_units_l3': 7, 'lr': 0.004018848737289436}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 17:58:30,369] Trial 21 finished with value: 43.26388168334961 and parameters: {'input_neurons': 25, 'n_layers': 4, 'n_units_l0': 68, 'n_units_l1': 28, 'n_units_l2': 94, 'n_units_l3': 128, 'lr': 0.02593767555510599}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 17:58:46,247] Trial 22 finished with value: 35.165672302246094 and parameters: {'input_neurons': 33, 'n_layers': 4, 'n_units_l0': 16, 'n_units_l1': 21, 'n_units_l2': 104, 'n_units_l3': 106, 'lr': 0.016651281528556144}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 17:59:02,233] Trial 23 finished with value: 66.98114013671875 and parameters: {'input_neurons': 34, 'n_layers': 4, 'n_units_l0': 19, 'n_units_l1': 20, 'n_units_l2': 106, 'n_units_l3': 101, 'lr': 0.0006885488369892988}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 17:59:24,176] Trial 24 finished with value: 32.374935150146484 and parameters: {'input_neurons': 49, 'n_layers': 4, 'n_units_l0': 15, 'n_units_l1': 41, 'n_units_l2': 76, 'n_units_l3': 100, 'lr': 0.042359999210396786}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 17:59:39,015] Trial 25 finished with value: 56.05976867675781 and parameters: {'input_neurons': 53, 'n_layers': 3, 'n_units_l0': 31, 'n_units_l1': 60, 'n_units_l2': 81, 'lr': 0.037015411477485126}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 17:59:50,339] Trial 26 finished with value: 60.7382698059082 and parameters: {'input_neurons': 67, 'n_layers': 4, 'n_units_l0': 16, 'n_units_l1': 41, 'n_units_l2': 81, 'n_units_l3': 97, 'lr': 0.005540790107991692}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:00:05,657] Trial 27 finished with value: 30.0262451171875 and parameters: {'input_neurons': 38, 'n_layers': 3, 'n_units_l0': 43, 'n_units_l1': 67, 'n_units_l2': 110, 'lr': 0.039926882168261846}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:00:26,983] Trial 28 finished with value: 41.335174560546875 and parameters: {'input_neurons': 41, 'n_layers': 2, 'n_units_l0': 44, 'n_units_l1': 86, 'lr': 0.048889476740860596}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:00:48,431] Trial 29 finished with value: 40.4549446105957 and parameters: {'input_neurons': 74, 'n_layers': 3, 'n_units_l0': 26, 'n_units_l1': 69, 'n_units_l2': 75, 'lr': 0.009479007394518917}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:01:09,869] Trial 30 finished with value: 76.38297271728516 and parameters: {'input_neurons': 58, 'n_layers': 3, 'n_units_l0': 60, 'n_units_l1': 97, 'n_units_l2': 110, 'lr': 0.0001635003140177676}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:01:31,919] Trial 31 finished with value: 85.13451385498047 and parameters: {'input_neurons': 35, 'n_layers': 4, 'n_units_l0': 12, 'n_units_l1': 40, 'n_units_l2': 110, 'n_units_l3': 92, 'lr': 0.04203375184021254}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:01:47,574] Trial 32 finished with value: 34.785675048828125 and parameters: {'input_neurons': 93, 'n_layers': 4, 'n_units_l0': 26, 'n_units_l1': 65, 'n_units_l2': 107, 'n_units_l3': 109, 'lr': 0.012339665136039749}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:02:08,997] Trial 33 finished with value: 64.20880126953125 and parameters: {'input_neurons': 92, 'n_layers': 3, 'n_units_l0': 27, 'n_units_l1': 61, 'n_units_l2': 116, 'lr': 0.0019851056349448415}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:02:23,358] Trial 34 finished with value: 33.516422271728516 and parameters: {'input_neurons': 99, 'n_layers': 4, 'n_units_l0': 38, 'n_units_l1': 77, 'n_units_l2': 49, 'n_units_l3': 113, 'lr': 0.04741847547194002}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:02:38,110] Trial 35 finished with value: 36.519657135009766 and parameters: {'input_neurons': 50, 'n_layers': 3, 'n_units_l0': 41, 'n_units_l1': 78, 'n_units_l2': 38, 'lr': 0.05446722044533946}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:02:59,640] Trial 36 finished with value: 32.326515197753906 and parameters: {'input_neurons': 128, 'n_layers': 4, 'n_units_l0': 48, 'n_units_l1': 91, 'n_units_l2': 39, 'n_units_l3': 84, 'lr': 0.03418514682126178}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:03:12,616] Trial 37 finished with value: 74.81782531738281 and parameters: {'input_neurons': 124, 'n_layers': 1, 'n_units_l0': 48, 'lr': 0.0012588676542636763}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:03:25,674] Trial 38 finished with value: 54.5320930480957 and parameters: {'input_neurons': 46, 'n_layers': 3, 'n_units_l0': 56, 'n_units_l1': 93, 'n_units_l2': 9, 'lr': 0.004809446097563633}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:03:46,967] Trial 39 finished with value: 94.95571899414062 and parameters: {'input_neurons': 115, 'n_layers': 2, 'n_units_l0': 62, 'n_units_l1': 112, 'lr': 7.383855780322002e-05}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:04:01,913] Trial 40 finished with value: 35.19346237182617 and parameters: {'input_neurons': 67, 'n_layers': 4, 'n_units_l0': 34, 'n_units_l1': 108, 'n_units_l2': 75, 'n_units_l3': 87, 'lr': 0.027866646978309036}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:04:23,432] Trial 41 finished with value: 36.31193161010742 and parameters: {'input_neurons': 103, 'n_layers': 4, 'n_units_l0': 39, 'n_units_l1': 87, 'n_units_l2': 48, 'n_units_l3': 84, 'lr': 0.05633013611706206}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:04:39,100] Trial 42 finished with value: 37.36354064941406 and parameters: {'input_neurons': 119, 'n_layers': 4, 'n_units_l0': 46, 'n_units_l1': 53, 'n_units_l2': 40, 'n_units_l3': 115, 'lr': 0.03489622076724989}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:04:54,297] Trial 43 finished with value: 39.79353332519531 and parameters: {'input_neurons': 128, 'n_layers': 4, 'n_units_l0': 33, 'n_units_l1': 75, 'n_units_l2': 49, 'n_units_l3': 53, 'lr': 0.06716414329100898}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:05:10,503] Trial 44 finished with value: 34.16911315917969 and parameters: {'input_neurons': 17, 'n_layers': 4, 'n_units_l0': 54, 'n_units_l1': 84, 'n_units_l2': 31, 'n_units_l3': 116, 'lr': 0.09962741751803084}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:05:21,664] Trial 45 finished with value: 61.130279541015625 and parameters: {'input_neurons': 105, 'n_layers': 3, 'n_units_l0': 21, 'n_units_l1': 105, 'n_units_l2': 57, 'lr': 0.010657623059872615}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:05:37,640] Trial 46 finished with value: 36.76199722290039 and parameters: {'input_neurons': 53, 'n_layers': 4, 'n_units_l0': 13, 'n_units_l1': 69, 'n_units_l2': 55, 'n_units_l3': 84, 'lr': 0.019835513248993672}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:05:49,231] Trial 47 finished with value: 62.859413146972656 and parameters: {'input_neurons': 95, 'n_layers': 4, 'n_units_l0': 40, 'n_units_l1': 48, 'n_units_l2': 70, 'n_units_l3': 99, 'lr': 0.0029217533020835106}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:06:01,977] Trial 48 finished with value: 31.863197326660156 and parameters: {'input_neurons': 76, 'n_layers': 3, 'n_units_l0': 71, 'n_units_l1': 59, 'n_units_l2': 38, 'lr': 0.06940687461782008}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:06:16,786] Trial 49 finished with value: 99.99655151367188 and parameters: {'input_neurons': 74, 'n_layers': 3, 'n_units_l0': 85, 'n_units_l1': 56, 'n_units_l2': 21, 'lr': 1.1550456973359922e-05}. Best is trial 17 with value: 29.427295684814453.
# [I 2024-03-06 18:06:38,313] Trial 50 finished with value: 29.100194931030273 and parameters: {'input_neurons': 40, 'n_layers': 2, 'n_units_l0': 75, 'n_units_l1': 37, 'lr': 0.07658536107403009}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:06:44,009] Trial 51 finished with value: 62.188575744628906 and parameters: {'input_neurons': 39, 'n_layers': 2, 'n_units_l0': 73, 'n_units_l1': 36, 'lr': 0.06519748503867909}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:07:05,631] Trial 52 finished with value: 44.0366096496582 and parameters: {'input_neurons': 45, 'n_layers': 2, 'n_units_l0': 83, 'n_units_l1': 49, 'lr': 0.026954386091690635}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:07:19,532] Trial 53 finished with value: 41.74223327636719 and parameters: {'input_neurons': 63, 'n_layers': 2, 'n_units_l0': 67, 'n_units_l1': 121, 'lr': 0.07371270829312854}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:07:40,966] Trial 54 finished with value: 38.35530471801758 and parameters: {'input_neurons': 52, 'n_layers': 3, 'n_units_l0': 94, 'n_units_l1': 24, 'n_units_l2': 13, 'lr': 0.03405790255950497}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:08:02,124] Trial 55 finished with value: 68.17422485351562 and parameters: {'input_neurons': 19, 'n_layers': 1, 'n_units_l0': 83, 'lr': 0.013769874947726546}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:08:23,433] Trial 56 finished with value: 33.85654830932617 and parameters: {'input_neurons': 81, 'n_layers': 2, 'n_units_l0': 72, 'n_units_l1': 37, 'lr': 0.09912670680996766}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:08:34,830] Trial 57 finished with value: 47.289180755615234 and parameters: {'input_neurons': 41, 'n_layers': 3, 'n_units_l0': 61, 'n_units_l1': 44, 'n_units_l2': 30, 'lr': 0.020927141137529887}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:08:56,104] Trial 58 finished with value: 38.299983978271484 and parameters: {'input_neurons': 58, 'n_layers': 2, 'n_units_l0': 100, 'n_units_l1': 13, 'lr': 0.04127208071096962}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:09:10,939] Trial 59 finished with value: 38.777156829833984 and parameters: {'input_neurons': 86, 'n_layers': 3, 'n_units_l0': 80, 'n_units_l1': 59, 'n_units_l2': 39, 'lr': 0.008574661528835008}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:09:32,367] Trial 60 finished with value: 43.0482177734375 and parameters: {'input_neurons': 32, 'n_layers': 3, 'n_units_l0': 64, 'n_units_l1': 33, 'n_units_l2': 65, 'lr': 0.07438635960671218}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:09:45,760] Trial 61 finished with value: 33.34992980957031 and parameters: {'input_neurons': 110, 'n_layers': 4, 'n_units_l0': 10, 'n_units_l1': 80, 'n_units_l2': 28, 'n_units_l3': 117, 'lr': 0.049970278619936824}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:10:01,519] Trial 62 finished with value: 29.447250366210938 and parameters: {'input_neurons': 109, 'n_layers': 4, 'n_units_l0': 11, 'n_units_l1': 65, 'n_units_l2': 28, 'n_units_l3': 33, 'lr': 0.020782700374738103}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:10:23,926] Trial 63 finished with value: 41.69147872924805 and parameters: {'input_neurons': 38, 'n_layers': 4, 'n_units_l0': 9, 'n_units_l1': 64, 'n_units_l2': 16, 'n_units_l3': 34, 'lr': 0.023590860162776655}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:10:39,987] Trial 64 finished with value: 33.007957458496094 and parameters: {'input_neurons': 115, 'n_layers': 4, 'n_units_l0': 5, 'n_units_l1': 52, 'n_units_l2': 34, 'n_units_l3': 28, 'lr': 0.01589395181001601}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:11:01,513] Trial 65 finished with value: 31.995126724243164 and parameters: {'input_neurons': 48, 'n_layers': 4, 'n_units_l0': 16, 'n_units_l1': 46, 'n_units_l2': 86, 'n_units_l3': 36, 'lr': 0.03689263135268592}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:11:11,977] Trial 66 finished with value: 65.14472961425781 and parameters: {'input_neurons': 63, 'n_layers': 1, 'n_units_l0': 22, 'lr': 0.03445907651709144}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:11:28,267] Trial 67 finished with value: 74.94157409667969 and parameters: {'input_neurons': 29, 'n_layers': 4, 'n_units_l0': 117, 'n_units_l1': 45, 'n_units_l2': 98, 'n_units_l3': 42, 'lr': 0.0003203996862747941}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:11:35,887] Trial 68 finished with value: 63.313026428222656 and parameters: {'input_neurons': 127, 'n_layers': 3, 'n_units_l0': 30, 'n_units_l1': 71, 'n_units_l2': 88, 'lr': 0.00765984517641462}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:11:47,622] Trial 69 finished with value: 59.646915435791016 and parameters: {'input_neurons': 55, 'n_layers': 4, 'n_units_l0': 18, 'n_units_l1': 58, 'n_units_l2': 117, 'n_units_l3': 17, 'lr': 0.017471950964273047}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:12:09,542] Trial 70 finished with value: 33.302207946777344 and parameters: {'input_neurons': 70, 'n_layers': 3, 'n_units_l0': 57, 'n_units_l1': 66, 'n_units_l2': 83, 'lr': 0.07491749025942697}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:12:25,240] Trial 71 finished with value: 29.226768493652344 and parameters: {'input_neurons': 49, 'n_layers': 4, 'n_units_l0': 12, 'n_units_l1': 39, 'n_units_l2': 69, 'n_units_l3': 51, 'lr': 0.043590890983189946}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:12:34,762] Trial 72 finished with value: 44.948604583740234 and parameters: {'input_neurons': 46, 'n_layers': 4, 'n_units_l0': 12, 'n_units_l1': 27, 'n_units_l2': 24, 'n_units_l3': 60, 'lr': 0.027105249962623368}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:12:51,828] Trial 73 finished with value: 33.2113151550293 and parameters: {'input_neurons': 36, 'n_layers': 4, 'n_units_l0': 50, 'n_units_l1': 37, 'n_units_l2': 100, 'n_units_l3': 43, 'lr': 0.05447736842547415}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:13:07,102] Trial 74 finished with value: 35.659637451171875 and parameters: {'input_neurons': 48, 'n_layers': 4, 'n_units_l0': 24, 'n_units_l1': 33, 'n_units_l2': 61, 'n_units_l3': 50, 'lr': 0.039768740944117274}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:13:29,121] Trial 75 finished with value: 50.284122467041016 and parameters: {'input_neurons': 41, 'n_layers': 4, 'n_units_l0': 16, 'n_units_l1': 51, 'n_units_l2': 43, 'n_units_l3': 76, 'lr': 0.02267802711364284}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:13:41,880] Trial 76 finished with value: 33.95988845825195 and parameters: {'input_neurons': 123, 'n_layers': 4, 'n_units_l0': 70, 'n_units_l1': 45, 'n_units_l2': 71, 'n_units_l3': 27, 'lr': 0.03144675888408023}. Best is trial 50 with value: 29.100194931030273.
# [I 2024-03-06 18:14:03,430] Trial 77 finished with value: 28.639894485473633 and parameters: {'input_neurons': 58, 'n_layers': 4, 'n_units_l0': 78, 'n_units_l1': 40, 'n_units_l2': 91, 'n_units_l3': 38, 'lr': 0.013401661313056111}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:14:24,965] Trial 78 finished with value: 41.827850341796875 and parameters: {'input_neurons': 56, 'n_layers': 4, 'n_units_l0': 79, 'n_units_l1': 47, 'n_units_l2': 85, 'n_units_l3': 36, 'lr': 0.061143397453769635}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:14:36,402] Trial 79 finished with value: 60.350704193115234 and parameters: {'input_neurons': 60, 'n_layers': 2, 'n_units_l0': 90, 'n_units_l1': 40, 'lr': 0.013038547982275266}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:14:47,927] Trial 80 finished with value: 39.801021575927734 and parameters: {'input_neurons': 74, 'n_layers': 4, 'n_units_l0': 77, 'n_units_l1': 54, 'n_units_l2': 93, 'n_units_l3': 52, 'lr': 0.08261314399210361}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:14:54,536] Trial 81 finished with value: 64.58822631835938 and parameters: {'input_neurons': 50, 'n_layers': 4, 'n_units_l0': 9, 'n_units_l1': 30, 'n_units_l2': 91, 'n_units_l3': 18, 'lr': 0.042334839189173135}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:15:10,165] Trial 82 finished with value: 40.37604904174805 and parameters: {'input_neurons': 43, 'n_layers': 4, 'n_units_l0': 88, 'n_units_l1': 63, 'n_units_l2': 103, 'n_units_l3': 62, 'lr': 0.015702452836709846}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:15:27,353] Trial 83 finished with value: 47.72157669067383 and parameters: {'input_neurons': 65, 'n_layers': 4, 'n_units_l0': 65, 'n_units_l1': 40, 'n_units_l2': 79, 'n_units_l3': 44, 'lr': 0.03122948001766869}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:15:42,705] Trial 84 finished with value: 39.24537658691406 and parameters: {'input_neurons': 70, 'n_layers': 4, 'n_units_l0': 69, 'n_units_l1': 35, 'n_units_l2': 86, 'n_units_l3': 33, 'lr': 0.05104731930990361}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:16:04,793] Trial 85 finished with value: 40.578006744384766 and parameters: {'input_neurons': 89, 'n_layers': 4, 'n_units_l0': 29, 'n_units_l1': 56, 'n_units_l2': 97, 'n_units_l3': 71, 'lr': 0.019112490051290586}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:16:18,948] Trial 86 finished with value: 58.84312438964844 and parameters: {'input_neurons': 77, 'n_layers': 2, 'n_units_l0': 18, 'n_units_l1': 92, 'lr': 0.006425280577092685}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:16:40,373] Trial 87 finished with value: 37.7003288269043 and parameters: {'input_neurons': 53, 'n_layers': 3, 'n_units_l0': 75, 'n_units_l1': 41, 'n_units_l2': 52, 'lr': 0.010578197457559549}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:17:01,927] Trial 88 finished with value: 33.836639404296875 and parameters: {'input_neurons': 116, 'n_layers': 4, 'n_units_l0': 43, 'n_units_l1': 24, 'n_units_l2': 114, 'n_units_l3': 18, 'lr': 0.025165008782426244}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:17:17,746] Trial 89 finished with value: 32.703765869140625 and parameters: {'input_neurons': 30, 'n_layers': 4, 'n_units_l0': 13, 'n_units_l1': 31, 'n_units_l2': 122, 'n_units_l3': 57, 'lr': 0.06046133137918161}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:17:39,311] Trial 90 finished with value: 99.80743408203125 and parameters: {'input_neurons': 98, 'n_layers': 4, 'n_units_l0': 8, 'n_units_l1': 73, 'n_units_l2': 43, 'n_units_l3': 25, 'lr': 2.8616945308408284e-05}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:17:48,698] Trial 91 finished with value: 33.40656280517578 and parameters: {'input_neurons': 49, 'n_layers': 4, 'n_units_l0': 23, 'n_units_l1': 46, 'n_units_l2': 77, 'n_units_l3': 77, 'lr': 0.04489863256180077}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:18:10,649] Trial 92 finished with value: 36.739261627197266 and parameters: {'input_neurons': 44, 'n_layers': 4, 'n_units_l0': 15, 'n_units_l1': 42, 'n_units_l2': 67, 'n_units_l3': 121, 'lr': 0.0389885034968743}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:18:26,454] Trial 93 finished with value: 30.829160690307617 and parameters: {'input_neurons': 56, 'n_layers': 4, 'n_units_l0': 36, 'n_units_l1': 38, 'n_units_l2': 71, 'n_units_l3': 104, 'lr': 0.07786492203676657}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:18:47,966] Trial 94 finished with value: 66.99156188964844 and parameters: {'input_neurons': 59, 'n_layers': 4, 'n_units_l0': 34, 'n_units_l1': 51, 'n_units_l2': 71, 'n_units_l3': 40, 'lr': 0.07488727373796314}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:19:09,512] Trial 95 finished with value: 40.627105712890625 and parameters: {'input_neurons': 63, 'n_layers': 4, 'n_units_l0': 37, 'n_units_l1': 38, 'n_units_l2': 59, 'n_units_l3': 106, 'lr': 0.08563489624931474}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:19:25,009] Trial 96 finished with value: 41.80144500732422 and parameters: {'input_neurons': 56, 'n_layers': 4, 'n_units_l0': 58, 'n_units_l1': 26, 'n_units_l2': 5, 'n_units_l3': 48, 'lr': 0.02944937302527739}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:19:38,751] Trial 97 finished with value: 39.6637077331543 and parameters: {'input_neurons': 47, 'n_layers': 4, 'n_units_l0': 52, 'n_units_l1': 18, 'n_units_l2': 34, 'n_units_l3': 93, 'lr': 0.06292703386071155}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:20:00,149] Trial 98 finished with value: 42.968196868896484 and parameters: {'input_neurons': 105, 'n_layers': 3, 'n_units_l0': 5, 'n_units_l1': 68, 'n_units_l2': 110, 'lr': 0.09467283396019467}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:20:15,888] Trial 99 finished with value: 64.65744018554688 and parameters: {'input_neurons': 37, 'n_layers': 4, 'n_units_l0': 20, 'n_units_l1': 48, 'n_units_l2': 93, 'n_units_l3': 124, 'lr': 0.0008934144568832413}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:20:29,628] Trial 100 finished with value: 33.3951416015625 and parameters: {'input_neurons': 67, 'n_layers': 2, 'n_units_l0': 47, 'n_units_l1': 34, 'lr': 0.049842068799531104}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:20:44,894] Trial 101 finished with value: 34.653621673583984 and parameters: {'input_neurons': 52, 'n_layers': 4, 'n_units_l0': 12, 'n_units_l1': 38, 'n_units_l2': 81, 'n_units_l3': 93, 'lr': 0.03691599853070627}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:21:06,442] Trial 102 finished with value: 35.700462341308594 and parameters: {'input_neurons': 42, 'n_layers': 4, 'n_units_l0': 25, 'n_units_l1': 43, 'n_units_l2': 75, 'n_units_l3': 102, 'lr': 0.022120350151733935}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:21:17,724] Trial 103 finished with value: 38.579986572265625 and parameters: {'input_neurons': 56, 'n_layers': 4, 'n_units_l0': 15, 'n_units_l1': 103, 'n_units_l2': 69, 'n_units_l3': 107, 'lr': 0.04796281073345368}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:21:29,246] Trial 104 finished with value: 43.52959060668945 and parameters: {'input_neurons': 61, 'n_layers': 4, 'n_units_l0': 44, 'n_units_l1': 55, 'n_units_l2': 73, 'n_units_l3': 36, 'lr': 0.06344594872067105}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:21:50,802] Trial 105 finished with value: 34.10111618041992 and parameters: {'input_neurons': 34, 'n_layers': 4, 'n_units_l0': 7, 'n_units_l1': 61, 'n_units_l2': 65, 'n_units_l3': 79, 'lr': 0.031195463243993648}. Best is trial 77 with value: 28.639894485473633.
# [I 2024-03-06 18:22:07,662] Trial 106 finished with value: 26.494787216186523 and parameters: {'input_neurons': 39, 'n_layers': 4, 'n_units_l0': 28, 'n_units_l1': 50, 'n_units_l2': 88, 'n_units_l3': 30, 'lr': 0.02513631848196066}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:22:30,371] Trial 107 finished with value: 34.81132507324219 and parameters: {'input_neurons': 38, 'n_layers': 4, 'n_units_l0': 72, 'n_units_l1': 50, 'n_units_l2': 89, 'n_units_l3': 31, 'lr': 0.015773919712726885}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:22:52,383] Trial 108 finished with value: 31.795194625854492 and parameters: {'input_neurons': 40, 'n_layers': 4, 'n_units_l0': 28, 'n_units_l1': 62, 'n_units_l2': 102, 'n_units_l3': 67, 'lr': 0.026601015713333523}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:23:03,441] Trial 109 finished with value: 57.54643249511719 and parameters: {'input_neurons': 23, 'n_layers': 2, 'n_units_l0': 32, 'n_units_l1': 57, 'lr': 0.024117000859534166}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:23:19,426] Trial 110 finished with value: 32.68724822998047 and parameters: {'input_neurons': 51, 'n_layers': 4, 'n_units_l0': 28, 'n_units_l1': 59, 'n_units_l2': 102, 'n_units_l3': 22, 'lr': 0.018802001661894434}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:23:33,565] Trial 111 finished with value: 38.32854461669922 and parameters: {'input_neurons': 40, 'n_layers': 4, 'n_units_l0': 36, 'n_units_l1': 64, 'n_units_l2': 106, 'n_units_l3': 38, 'lr': 0.03635814913859953}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:23:47,314] Trial 112 finished with value: 40.924827575683594 and parameters: {'input_neurons': 47, 'n_layers': 4, 'n_units_l0': 80, 'n_units_l1': 44, 'n_units_l2': 96, 'n_units_l3': 46, 'lr': 0.02688224647248757}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:23:54,937] Trial 113 finished with value: 63.15250015258789 and parameters: {'input_neurons': 32, 'n_layers': 1, 'n_units_l0': 42, 'lr': 0.07992265383914701}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:24:09,747] Trial 114 finished with value: 32.855552673339844 and parameters: {'input_neurons': 43, 'n_layers': 4, 'n_units_l0': 39, 'n_units_l1': 62, 'n_units_l2': 99, 'n_units_l3': 10, 'lr': 0.043788527827872036}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:24:23,570] Trial 115 finished with value: 31.746652603149414 and parameters: {'input_neurons': 54, 'n_layers': 4, 'n_units_l0': 18, 'n_units_l1': 53, 'n_units_l2': 27, 'n_units_l3': 71, 'lr': 0.05484561631381235}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:24:39,297] Trial 116 finished with value: 46.81962585449219 and parameters: {'input_neurons': 44, 'n_layers': 4, 'n_units_l0': 18, 'n_units_l1': 48, 'n_units_l2': 19, 'n_units_l3': 66, 'lr': 0.014203804368273067}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:25:01,109] Trial 117 finished with value: 34.36875534057617 and parameters: {'input_neurons': 54, 'n_layers': 4, 'n_units_l0': 21, 'n_units_l1': 71, 'n_units_l2': 27, 'n_units_l3': 57, 'lr': 0.057442984566424195}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:25:22,551] Trial 118 finished with value: 34.1389045715332 and parameters: {'input_neurons': 49, 'n_layers': 3, 'n_units_l0': 11, 'n_units_l1': 67, 'n_units_l2': 86, 'lr': 0.06708984885834654}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:25:38,245] Trial 119 finished with value: 32.284149169921875 and parameters: {'input_neurons': 29, 'n_layers': 4, 'n_units_l0': 26, 'n_units_l1': 52, 'n_units_l2': 91, 'n_units_l3': 69, 'lr': 0.010977208426863855}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:25:46,440] Trial 120 finished with value: 44.415767669677734 and parameters: {'input_neurons': 36, 'n_layers': 3, 'n_units_l0': 23, 'n_units_l1': 31, 'n_units_l2': 108, 'lr': 0.05291882576911633}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:26:02,430] Trial 121 finished with value: 34.45317459106445 and parameters: {'input_neurons': 28, 'n_layers': 4, 'n_units_l0': 26, 'n_units_l1': 53, 'n_units_l2': 92, 'n_units_l3': 67, 'lr': 0.010136170913094197}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:26:23,985] Trial 122 finished with value: 34.42179870605469 and parameters: {'input_neurons': 19, 'n_layers': 4, 'n_units_l0': 27, 'n_units_l1': 60, 'n_units_l2': 84, 'n_units_l3': 62, 'lr': 0.011597938927499076}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:26:39,795] Trial 123 finished with value: 34.48374938964844 and parameters: {'input_neurons': 39, 'n_layers': 4, 'n_units_l0': 30, 'n_units_l1': 39, 'n_units_l2': 114, 'n_units_l3': 73, 'lr': 0.00424625322448313}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:27:01,344] Trial 124 finished with value: 30.14249038696289 and parameters: {'input_neurons': 27, 'n_layers': 4, 'n_units_l0': 17, 'n_units_l1': 54, 'n_units_l2': 89, 'n_units_l3': 30, 'lr': 0.03080611240735949}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:27:17,297] Trial 125 finished with value: 35.89723205566406 and parameters: {'input_neurons': 57, 'n_layers': 4, 'n_units_l0': 15, 'n_units_l1': 57, 'n_units_l2': 88, 'n_units_l3': 31, 'lr': 0.022089505579293726}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:27:32,733] Trial 126 finished with value: 36.225521087646484 and parameters: {'input_neurons': 25, 'n_layers': 4, 'n_units_l0': 18, 'n_units_l1': 45, 'n_units_l2': 95, 'n_units_l3': 22, 'lr': 0.03183081060910434}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:27:54,257] Trial 127 finished with value: 37.861595153808594 and parameters: {'input_neurons': 15, 'n_layers': 4, 'n_units_l0': 9, 'n_units_l1': 65, 'n_units_l2': 79, 'n_units_l3': 29, 'lr': 0.09917872920987318}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:28:09,993] Trial 128 finished with value: 38.63483810424805 and parameters: {'input_neurons': 33, 'n_layers': 4, 'n_units_l0': 77, 'n_units_l1': 43, 'n_units_l2': 104, 'n_units_l3': 25, 'lr': 0.04077586176092632}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:28:25,627] Trial 129 finished with value: 34.999813079833984 and parameters: {'input_neurons': 46, 'n_layers': 4, 'n_units_l0': 20, 'n_units_l1': 54, 'n_units_l2': 23, 'n_units_l3': 39, 'lr': 0.018643184948191876}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:28:39,966] Trial 130 finished with value: 57.0504150390625 and parameters: {'input_neurons': 64, 'n_layers': 4, 'n_units_l0': 83, 'n_units_l1': 36, 'n_units_l2': 100, 'n_units_l3': 42, 'lr': 0.001972464204642466}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:29:01,476] Trial 131 finished with value: 31.750629425048828 and parameters: {'input_neurons': 27, 'n_layers': 4, 'n_units_l0': 14, 'n_units_l1': 50, 'n_units_l2': 90, 'n_units_l3': 55, 'lr': 0.026156752324056804}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:29:16,797] Trial 132 finished with value: 31.699678421020508 and parameters: {'input_neurons': 27, 'n_layers': 4, 'n_units_l0': 15, 'n_units_l1': 50, 'n_units_l2': 83, 'n_units_l3': 34, 'lr': 0.02680536617351429}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:29:33,963] Trial 133 finished with value: 31.285541534423828 and parameters: {'input_neurons': 21, 'n_layers': 4, 'n_units_l0': 11, 'n_units_l1': 50, 'n_units_l2': 83, 'n_units_l3': 56, 'lr': 0.026111265988956057}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:29:51,877] Trial 134 finished with value: 38.620201110839844 and parameters: {'input_neurons': 9, 'n_layers': 4, 'n_units_l0': 13, 'n_units_l1': 48, 'n_units_l2': 82, 'n_units_l3': 53, 'lr': 0.027496017374991667}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:30:07,974] Trial 135 finished with value: 30.6436767578125 and parameters: {'input_neurons': 23, 'n_layers': 4, 'n_units_l0': 7, 'n_units_l1': 55, 'n_units_l2': 78, 'n_units_l3': 50, 'lr': 0.023642164806039583}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:30:15,255] Trial 136 finished with value: 62.15022277832031 and parameters: {'input_neurons': 22, 'n_layers': 4, 'n_units_l0': 7, 'n_units_l1': 51, 'n_units_l2': 78, 'n_units_l3': 55, 'lr': 0.020304843360389267}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:30:22,590] Trial 137 finished with value: 61.137420654296875 and parameters: {'input_neurons': 16, 'n_layers': 4, 'n_units_l0': 10, 'n_units_l1': 41, 'n_units_l2': 73, 'n_units_l3': 48, 'lr': 0.01689431367105224}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:30:44,143] Trial 138 finished with value: 34.122432708740234 and parameters: {'input_neurons': 25, 'n_layers': 4, 'n_units_l0': 5, 'n_units_l1': 50, 'n_units_l2': 127, 'n_units_l3': 59, 'lr': 0.013642508975619649}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:31:00,181] Trial 139 finished with value: 33.2771110534668 and parameters: {'input_neurons': 12, 'n_layers': 4, 'n_units_l0': 11, 'n_units_l1': 56, 'n_units_l2': 80, 'n_units_l3': 45, 'lr': 0.02344504324284423}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:31:21,738] Trial 140 finished with value: 86.97472381591797 and parameters: {'input_neurons': 21, 'n_layers': 4, 'n_units_l0': 14, 'n_units_l1': 46, 'n_units_l2': 89, 'n_units_l3': 35, 'lr': 0.00017087420245803968}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:31:37,585] Trial 141 finished with value: 39.76103210449219 and parameters: {'input_neurons': 27, 'n_layers': 4, 'n_units_l0': 18, 'n_units_l1': 53, 'n_units_l2': 87, 'n_units_l3': 50, 'lr': 0.02698315557955077}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:31:59,149] Trial 142 finished with value: 36.882728576660156 and parameters: {'input_neurons': 30, 'n_layers': 4, 'n_units_l0': 7, 'n_units_l1': 63, 'n_units_l2': 82, 'n_units_l3': 63, 'lr': 0.03286836291183256}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:32:15,164] Trial 143 finished with value: 39.58552169799805 and parameters: {'input_neurons': 20, 'n_layers': 4, 'n_units_l0': 11, 'n_units_l1': 59, 'n_units_l2': 94, 'n_units_l3': 31, 'lr': 0.043496549426414295}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:32:30,493] Trial 144 finished with value: 30.334644317626953 and parameters: {'input_neurons': 26, 'n_layers': 4, 'n_units_l0': 17, 'n_units_l1': 55, 'n_units_l2': 83, 'n_units_l3': 41, 'lr': 0.029918426498580935}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:32:37,405] Trial 145 finished with value: 54.70796203613281 and parameters: {'input_neurons': 23, 'n_layers': 4, 'n_units_l0': 16, 'n_units_l1': 49, 'n_units_l2': 85, 'n_units_l3': 38, 'lr': 0.03471087626884093}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:32:48,708] Trial 146 finished with value: 43.522274017333984 and parameters: {'input_neurons': 26, 'n_layers': 4, 'n_units_l0': 9, 'n_units_l1': 35, 'n_units_l2': 75, 'n_units_l3': 41, 'lr': 0.02063825678604715}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:33:10,257] Trial 147 finished with value: 43.6430549621582 and parameters: {'input_neurons': 17, 'n_layers': 4, 'n_units_l0': 12, 'n_units_l1': 55, 'n_units_l2': 62, 'n_units_l3': 51, 'lr': 0.04970893729551143}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:33:32,059] Trial 148 finished with value: 34.698944091796875 and parameters: {'input_neurons': 31, 'n_layers': 4, 'n_units_l0': 23, 'n_units_l1': 42, 'n_units_l2': 83, 'n_units_l3': 47, 'lr': 0.03137505927284615}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:33:53,603] Trial 149 finished with value: 38.418216705322266 and parameters: {'input_neurons': 35, 'n_layers': 4, 'n_units_l0': 17, 'n_units_l1': 39, 'n_units_l2': 78, 'n_units_l3': 110, 'lr': 0.016440949943906113}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:34:15,160] Trial 150 finished with value: 33.56568908691406 and parameters: {'input_neurons': 27, 'n_layers': 4, 'n_units_l0': 21, 'n_units_l1': 47, 'n_units_l2': 90, 'n_units_l3': 55, 'lr': 0.02394666185092157}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:34:29,926] Trial 151 finished with value: 42.075714111328125 and parameters: {'input_neurons': 60, 'n_layers': 4, 'n_units_l0': 35, 'n_units_l1': 62, 'n_units_l2': 68, 'n_units_l3': 119, 'lr': 0.02865726393053692}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:34:51,481] Trial 152 finished with value: 34.30224609375 and parameters: {'input_neurons': 24, 'n_layers': 4, 'n_units_l0': 13, 'n_units_l1': 57, 'n_units_l2': 84, 'n_units_l3': 27, 'lr': 0.03867868349420398}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:35:08,283] Trial 153 finished with value: 32.26982116699219 and parameters: {'input_neurons': 54, 'n_layers': 4, 'n_units_l0': 14, 'n_units_l1': 53, 'n_units_l2': 73, 'n_units_l3': 32, 'lr': 0.02558590105059734}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:35:24,480] Trial 154 finished with value: 30.292448043823242 and parameters: {'input_neurons': 34, 'n_layers': 4, 'n_units_l0': 20, 'n_units_l1': 70, 'n_units_l2': 91, 'n_units_l3': 34, 'lr': 0.019259876523774547}. Best is trial 106 with value: 26.494787216186523.
# [I 2024-03-06 18:35:46,047] Trial 155 finished with value: 33.665409088134766 and parameters: {'input_neurons': 28, 'n_layers': 4, 'n_units_l0': 20, 'n_units_l1': 73, 'n_units_l2': 91, 'n_units_l3': 128, 'lr': 0.01384468680260857}. Best is trial 106 with value: 26.494787216186523.

# %%
model_1 = Sequential()
model_1.add(Dense(5, activation='relu', input_shape=(X_train.shape[1],)))  # Correct aantal input features
model_1.add(Dense(117, activation='relu'))
model_1.add(Dense(35, activation='relu'))
model_1.add(Dense(91, activation='relu'))
model_1.add(Dense(76, activation='relu'))
model_1.add(Dense(1, activation='linear'))

model_1.compile(optimizer=Adam(learning_rate=0.00664967481916384),
                loss='mean_squared_error',
                metrics=['mean_absolute_percentage_error'])

# Gebruik dezelfde early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

model_1.fit(X_train, y_train, validation_data=(X_test, y_test),
            epochs=100, batch_size=16, callbacks=[early_stop], verbose=0)

# Evalueer het model
loss, mape = model_1.evaluate(X_test, y_test, verbose=0)
print(f'Validation MAPE: {mape}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8fc3ea77cd33> in <cell line: 1>()
# ----> 1 model_1 = Sequential()
#       2 model_1.add(Dense(5, activation='relu', input_shape=(X_train.shape[1],)))  # Correct aantal input features
#       3 model_1.add(Dense(117, activation='relu'))
#       4 model_1.add(Dense(35, activation='relu'))
#       5 model_1.add(Dense(91, activation='relu'))
#
# NameError: name 'Sequential' is not defined

# %% [markdown]
# score op kaggle: 0,59605

# %% [markdown]
# **model_1_1**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
import numpy as np

# Modeldefinitie
model_1_1 = Sequential()
model_1_1.add(Dense(5, activation='relu', input_shape=(X_train.shape[1],)))  # Correct aantal input features
model_1_1.add(Dropout(0.2))  # Dropout toegevoegd
model_1_1.add(Dense(117, activation='relu'))
model_1_1.add(Dropout(0.2))  # Dropout toegevoegd
model_1_1.add(Dense(35, activation='relu'))
model_1_1.add(Dropout(0.2))  # Dropout toegevoegd
model_1_1.add(Dense(91, activation='relu'))
model_1_1.add(Dropout(0.2))  # Dropout toegevoegd
model_1_1.add(Dense(76, activation='relu'))
model_1_1.add(Dropout(0.2))  # Dropout toegevoegd
model_1_1.add(Dense(1, activation='linear'))

# Learning Rate Scheduler
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * np.exp(-0.1)

lr_schedule = LearningRateScheduler(scheduler)

# Compileer het model
model_1_1.compile(optimizer=Adam(learning_rate=0.00664967481916384),
                  loss='mean_squared_error',
                  metrics=['mean_absolute_percentage_error'])

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

# Train het model
# Zorg ervoor dat X_train, y_train, X_test, en y_test gedefinieerd zijn voordat je dit uitvoert.
model_1_1.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=16, callbacks=[early_stop, lr_schedule], verbose=0)

# Evalueer het model
loss, mape = model_1_1.evaluate(X_test, y_test, verbose=0)
print(f'Validation MAPE: {mape}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8b7af7dc69a8> in <cell line: 9>()
#       7 # Modeldefinitie
#       8 model_1_1 = Sequential()
# ----> 9 model_1_1.add(Dense(5, activation='relu', input_shape=(X_train.shape[1],)))  # Correct aantal input features
#      10 model_1_1.add(Dropout(0.2))  # Dropout toegevoegd
#      11 model_1_1.add(Dense(117, activation='relu'))
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# score op kaggle: 0,58263

# %% [markdown]
# **model_1_2**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.regularizers import l1_l2
import numpy as np

# Modeldefinitie
model_1_2 = Sequential([
    Dense(5, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=l1_l2(l1=0.01, l2=0.01)),
    Dropout(0.1),  # Lichtere dropout in de eerste laag
    Dense(120, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)),  # Aangepast aantal neuronen + regularisatie
    Dropout(0.2),
    Dense(40, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)),  # Aangepast aantal neuronen + regularisatie
    Dropout(0.25),
    Dense(80, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)),  # Aangepast aantal neuronen + regularisatie
    Dropout(0.3),
    Dense(70, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)),  # Aangepast aantal neuronen + regularisatie
    Dropout(0.35),
    Dense(1, activation='linear')
])

# Learning Rate Scheduler
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    elif epoch < 20:
        return lr * 0.9
    else:
        return lr * np.exp(-0.1)

lr_schedule = LearningRateScheduler(scheduler)

# Compileer het model
model_1_2.compile(optimizer=Adam(learning_rate=0.00664967481916384),
                  loss='mean_squared_error',
                  metrics=['mean_absolute_percentage_error'])

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train het model
model_1_2.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=16, callbacks=[early_stop, lr_schedule], verbose=0)

# Evalueer het model
loss, mape = model_1_2.evaluate(X_test, y_test, verbose=0)
print(f'Validation MAPE: {mape}')

# %% [markdown]
# score op kaggle: 0,99372

# %% [markdown]
# **model_1_3**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
import numpy as np

# Modeldefinitie
model_1_3 = Sequential([
    Dense(5, activation='relu', input_shape=(X_train.shape[1],)),  # Correct aantal input features
    Dropout(0.25),  # Licht verhoogde dropout
    Dense(117, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)),
    Dropout(0.25),
    Dense(35, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)),
    Dropout(0.25),
    Dense(91, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)),
    Dropout(0.25),
    Dense(76, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)),
    Dropout(0.25),
    Dense(1, activation='linear')
])

# Learning Rate Scheduler
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * np.exp(-0.2)  # Aangepaste verlagingssnelheid

lr_schedule = LearningRateScheduler(scheduler)

# Compileer het model
model_1_3.compile(optimizer=Adam(learning_rate=0.00664967481916384),  # Start learning rate
                  loss='mean_squared_error',
                  metrics=['mean_absolute_percentage_error'])

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Training van het model (zorg ervoor dat X_train, y_train, X_test, en y_test correct gedefinieerd zijn)
model_1_3.fit(X_train, y_train, validation_data=(X_test, y_test),
              epochs=100, batch_size=16, callbacks=[early_stop, lr_schedule], verbose=0)

# Evalueer het model
loss, mape = model_1_3.evaluate(X_test, y_test, verbose=0)
print(f'Validation MAPE: {mape}')

# %% [markdown]
# score op kaggle:  0,96494

# %% [markdown]
# **model_1_4**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
import numpy as np

# Modeldefinitie
model_1_4 = Sequential([
    Dense(5, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.15),  # Iets verlaagde dropout vergeleken met model_1_3
    Dense(117, activation='relu'),
    Dropout(0.15),
    Dense(35, activation='relu'),
    Dropout(0.15),
    Dense(91, activation='relu'),
    Dropout(0.15),
    Dense(76, activation='relu'),
    Dropout(0.15),
    Dense(1, activation='linear')
])

# Learning Rate Scheduler
def scheduler(epoch, lr):
    if epoch < 20:
        return lr
    else:
        return lr * np.exp(-0.05)  # Subtielere verlagingssnelheid

lr_schedule = LearningRateScheduler(scheduler)

# Compileer het model
model_1_4.compile(optimizer=Adam(learning_rate=0.00664967481916384),
                  loss='mean_squared_error',
                  metrics=['mean_absolute_percentage_error'])

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train het model
model_1_4.fit(X_train, y_train, validation_data=(X_test, y_test),
              epochs=100, batch_size=16, callbacks=[early_stop, lr_schedule], verbose=0)

# Evalueer het model
loss, mape = model_1_4.evaluate(X_test, y_test, verbose=0)
print(f'Validation MAPE: {mape}')

# %% [markdown]
# score op kaggle: 0,98515

# %% [markdown]
# **model_1_5**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

# Definieer de beste hyperparameters volgens Optuna's output
best_params = {
    'input_neurons': 127,
    'n_layers': 4,
    'n_units_l0': 14,
    'n_units_l1': 118,
    'n_units_l2': 128,
    'n_units_l3': 45,
    'lr': 0.01328913981701352
}

# Bouw het model met de beste hyperparameters
def build_model_with_best_params(params):
    model = Sequential()
    model.add(Dense(params['input_neurons'], activation='relu', input_shape=(X_train.shape[1],)))

    # Voeg de dynamisch bepaalde lagen toe
    layer_units = [params[f'n_units_l{i}'] for i in range(params['n_layers'])]
    for units in layer_units:
        model.add(Dense(units, activation='relu'))

    model.add(Dense(1, activation='linear'))

    return model

# Maak het model aan
model = build_model_with_best_params(best_params)

# Compileer het model met de beste learning rate
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mean_squared_error',
              metrics=['mean_absolute_percentage_error'])

# Stel de EarlyStopping callback in
early_stop = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

# Train het model
model.fit(X_train, y_train, validation_data=(X_test, y_test),
          epochs=100, batch_size=16, callbacks=[early_stop], verbose=0)

# Evalueer het model
loss, mape = model.evaluate(X_test, y_test, verbose=0)
print(f'Validation MAPE: {mape}')

# %% [markdown]
# # Modelaanpassingen en Verbeteringen
#
# In deze versie van het neurale netwerkmodel zijn verschillende aanpassingen gemaakt ten opzichte van de eerste versie van het model. Deze wijzigingen zijn bedoeld om de modelprestaties te verbeteren, zoals gemeten door een lagere Mean Absolute Percentage Error (MAPE) op Kaggle. Hier volgt een overzicht van de belangrijkste aanpassingen:
#
# ### Architectuur van het Model
# - **Verhoging van het Aantal Neuronen**: In elke laag van het model is het aantal neuronen aangepast om de modelcomplexiteit te verhogen. Dit stelt het model in staat om complexere patronen in de data te leren.
#     - De inputlaag en de eerste verborgen laag bevatten nu 128 neuronen.
#     - De tweede verborgen laag bevat 64 neuronen.
#     - De derde verborgen laag bevat 32 neuronen.
# - **Dropout Toegevoegd**: In elke verborgen laag is een dropout van 0.2 toegepast. Dropout helpt overfitting te verminderen door willekeurig een deel van de neuronen tijdens de training uit te schakelen, wat zorgt voor een robuuster netwerk.
#
# ### Hyperparameters
# - **Learning Rate**: De learning rate van de Adam optimizer is ingesteld op 0.001. Dit is een standaardwaarde die vaak een goed evenwicht biedt tussen snelheid en nauwkeurigheid van de training.
# - **Batch Size**: De batch size is vastgesteld op 32. Dit is een veelgebruikte grootte die een goede balans biedt tussen de snelheid van de training en de nauwkeurigheid van de gradient updates.
# - **Aantal Epochs**: Er is gekozen voor een maximum van 1000 epochs, met early stopping toegepast om te voorkomen dat het model te lang traint en overfit raakt.
#
# ### Training en Validatie
# - **Validation Split**: Een validatiesplit van 0.2 wordt gebruikt om een deel van de trainingsdata apart te zetten voor validatiedoeleinden. Dit helpt bij het monitoren van het modelprestaties op niet-getrainde data.
# - **Early Stopping**: Early stopping wordt gebruikt met een `patience` van 20 epochs. Dit betekent dat de training stopt als het validatieverlies voor 20 opeenvolgende epochs niet verbetert, waarbij de beste modelgewichten worden hersteld.
#
# Deze aanpassingen zijn gemaakt met het doel om de nauwkeurigheid van het model te verbeteren en overfitting te verminderen. Door het aantal neuronen te verhogen en dropout toe te passen, is het model beter in staat om de onderliggende patronen in de data te leren zonder te veel te leren van de ruis of specifieke details van de trainingsset.

# %% [markdown]
# **versie 2 van het model (voorspelling_FCNN-versie_2)** score: 0,57711

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import pandas as pd  # Zorg ervoor dat je pandas hebt geïmporteerd om met DataFrame te werken

# Aannemend dat train_data je DataFrame is met de trainingsdata
# Aanmaken van de random_state SEED
SEED = 42

# Opsplitsten van data in X en y
X = train_data.drop(['House ID', 'Price'], axis=1)
y = train_data['Price']

# Toepassen van train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=SEED)

# Modeldefinitie
model_2 = Sequential()

# Input layer en eerste hidden layer met Dropout
model_2.add(Dense(128, input_shape=(X_train.shape[1],), activation='relu'))
model_2.add(Dropout(0.2))

# Tweede hidden layer
model_2.add(Dense(64, activation='relu'))
model_2.add(Dropout(0.2))

# Derde hidden layer
model_2.add(Dense(32, activation='relu'))
model_2.add(Dropout(0.2))

# Output layer
model_2.add(Dense(1, activation='linear'))

# Compileer het model
model_2.compile(optimizer=Adam(learning_rate=0.001),
                loss='mean_squared_error',
                metrics=['mean_absolute_error'])

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train het model
history = model_2.fit(X_train, y_train,
                      batch_size=32,
                      epochs=1000,
                      validation_data=(X_val, y_val),
                      callbacks=[early_stop])

# %% [markdown]
# **model versie 3 (voorspelling_FCNN-versie_3)** score: 0,99946

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Modeldefinitie
model_3 = Sequential()

# Input layer en eerste hidden layer met Dropout
model_3.add(Dense(128, input_shape=(X_train.shape[1],)))
model_3.add(BatchNormalization())
model_3.add(LeakyReLU(alpha=0.01))
model_3.add(Dropout(0.1))  # Verlaagde dropout

# Tweede hidden layer
model_3.add(Dense(64))
model_3.add(BatchNormalization())
model_3.add(LeakyReLU(alpha=0.01))
model_3.add(Dropout(0.1))  # Verlaagde dropout

# Derde hidden layer
model_3.add(Dense(32))
model_3.add(BatchNormalization())
model_3.add(LeakyReLU(alpha=0.01))
model_3.add(Dropout(0.1))  # Verlaagde dropout

# Output layer
model_3.add(Dense(1, activation='linear'))

# Compileer het model
model_3.compile(optimizer=Adam(learning_rate=0.0009),  # Fijn afgestemde learning rate
              loss='mean_absolute_percentage_error',  # Verandering van loss functie
              metrics=['mean_absolute_error'])

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train het model
history = model_3.fit(X_train, y_train,
                    batch_size=32,
                    epochs=500,  # Verminderde het aantal epochs
                    validation_split=0.2,
                    callbacks=[early_stop])

# %% [markdown]
# **model versie 4 (voorspelling_FCNN-versie_4)** score: 0,57714

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Modeldefinitie
model_4 = Sequential()

# Input layer en eerste hidden layer met Dropout
model_4.add(Dense(128, input_shape=(X_train.shape[1],), activation='relu'))
model_4.add(Dropout(0.1))  # Een lichtere dropout kan soms beter presteren

# Tweede hidden layer
model_4.add(Dense(64, activation='relu'))
model_4.add(Dropout(0.1))  # Consistent houden van dropout

# Derde hidden layer
model_4.add(Dense(32, activation='relu'))
model_4.add(Dropout(0.1))  # Consistent houden van dropout

# Output layer
model_4.add(Dense(1, activation='linear'))

# Compileer het model
model_4.compile(optimizer=Adam(learning_rate=0.001),  # Terug naar de originele learning rate
              loss='mean_squared_error',  # Gebruik MSE zoals in het tweede model
              metrics=['mean_absolute_percentage_error'])  # Voor directe feedback over de MAPE score

# Early stopping callback om te voorkomen dat we overfitting krijgen
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# Train het model
history = model_4.fit(X_train, y_train,
                    batch_size=32,
                    epochs=500,  # Een gemiddeld aantal epochs
                    validation_split=0.2,
                    callbacks=[early_stop])

# %% [markdown]
# **versie 5 van het model(voorspelling_FCNN-versie_5)** score: 0,99971

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Modeldefinitie
model_5 = Sequential()

# Input layer
model_5.add(Dense(256, input_shape=(X_train.shape[1],), activation='relu'))
model_5.add(BatchNormalization())  # Verbeterde normalisatie

# Eerste hidden layer met Dropout
model_5.add(Dense(256, activation='relu'))
model_5.add(Dropout(0.3))  # Iets verhoogde dropout voor deze laag

# Tweede hidden layer
model_5.add(Dense(128, activation='relu'))
model_5.add(BatchNormalization())

# Derde hidden layer met Dropout
model_5.add(Dense(64, activation='relu'))
model_5.add(Dropout(0.2))

# Vierde hidden layer
model_5.add(Dense(64, activation='relu'))
model_5.add(BatchNormalization())

# Output layer
model_5.add(Dense(1, activation='linear'))

# Compileer het model
model_5.compile(optimizer=Adam(learning_rate=0.0005),  # Aangepaste learning rate
                loss='mean_absolute_percentage_error',  # Gebruik MAPE als loss functie
                metrics=['mean_absolute_error'])

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train het model
history = model_5.fit(X_train, y_train,
                      batch_size=64,  # Aangepaste batch size
                      epochs=400,  # Aangepaste aantal epochs
                      validation_split=0.2,
                      callbacks=[early_stop])

# %% [markdown]
# **versie 6 van het model(voorspelling_FCNN-versie_6)** score: 0,99

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Modeldefinitie
model_6 = Sequential()

# Input layer
model_6.add(Dense(256, input_shape=(X_train.shape[1],)))
model_6.add(BatchNormalization())
model_6.add(Activation('relu'))
model_6.add(Dropout(0.3))

# Toevoegen van meer hidden layers met verhoogde dropout
model_6.add(Dense(128))
model_6.add(BatchNormalization())
model_6.add(Activation('relu'))
model_6.add(Dropout(0.3))

model_6.add(Dense(64))
model_6.add(BatchNormalization())
model_6.add(Activation('relu'))
model_6.add(Dropout(0.3))

# Output layer
model_6.add(Dense(1, activation='linear'))

# Compileer het model
model_6.compile(optimizer=Adam(learning_rate=0.0005),
                loss='mean_squared_error',
                metrics=['mean_absolute_percentage_error'])

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train het model
history = model_6.fit(X_train, y_train,
                      batch_size=32,
                      epochs=800,  # Aangepast aantal epochs
                      validation_split=0.2,
                      callbacks=[early_stop])

# %% [markdown]
# Met die code heb ik het eerste model opgeslagen in een nieuwe map genaamd modelversies

# %%
def kaggle_csv(model, suffix):
    """
    Deze functie maakt de voorspelling op de test dataset
    en vormt deze om tot een csv bestand om in te kunnen
    leveren op Kaggle.

    Parameters:
    ----------
    model : ML-model of DL-model
        De naam die is gegeven aan het ML-model of DL-model
        dat wordt gebruikt om te voorspellen

    suffix : str
        De 'tag' voor de naam van het csv
        bestand, zodat deze makkelijk te identificeren
        is na de submission.

    Returns:
    ----------
    None
        In plaats van een return maakt het een bestand
        aan in de map Kaggle Submissions. De namen zien
        er als volgt uit:

    """
    # Aanmaken van de voorspelling
    y_pred = model.predict(sc_test_fe)

    # Aanmaken df met alleen House ID en Price
    test_predictions_df = pd.DataFrame(
        {'House ID': test_data['House ID'],
        'Price': np.ravel(y_pred)})

    # Aanmaken van tijd
    tijd = datetime.datetime.now().strftime("%m%d%H%M%S")

    # Aanmaken csv bestand met timestamp
    test_predictions_df.to_csv(
        f'Kaggle/voorspelling_{suffix}_{tijd}.csv',
        index=False)

    # Print voor conformatie
    print(f'voorspelling_{suffix}_{tijd}.csv has been saved!')

# %% [markdown]
# Nu zal de functie worden uitgevoerd om de voorspellingen te verkrijgen.

# %%
# Uitvoeren van kaggle_csv functie
kaggle_csv(model_1_4, 'FCNN-versie_1_4')

# %% [markdown]
# - [ ] Bouw en train een dense (fully-connected) netwerk om de huizenprijzen te voorspellen op basis van de tabular data.

# %% [markdown]
# - [ ] Beschrijf welke lossfunctie het meest geschikt is voor dit probleem. Kies een geschikte optimizer en beschrijf kort hoe deze optimizer werkt.

# %% [markdown]
# - [ ] Plot je modelarchitectuur met behulp van een geschikte visualisatietool.
# - [ ] Onderbouw je keuzes van het aantal convolutionele lagen, poollagen, convolutionele kernels per laag, het aantal fully-connected lagen en het aantal neuronen per laag.

# %% [markdown]
# ## CNN from Scratch

# %% [markdown]
# - [ ] Plot je modelarchitectuur met behulp van een geschikte visualisatietool.
# - [ ] Onderbouw je keuzes van het aantal lagen, het aantal neuronen per laag, de activeringsfuncties, de keuze van optimizer en het aantal trainingsepochs.

# %% [markdown]
# - [ ] Gebruik een of meer van de volgende technieken in je model. Beschrijf en motiveer je keuze:
#     - [ ] L1 regularisatie
#     - [ ] L2 regularisatie
#     - [ ] Dropout
#     - [ ] Batchnorm

# %% [markdown]
# - [ ] Beschrijf welke vormen van data augmentation (indien van toepassing) geschikt zijn voor dit probleem. Implementeer dit in je datapijplijn.
# - [ ] Compile je model met je gekozen lossfunctie en optimizer, en train deze op de afbeeldingen.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Modeldefinitie
model_2 = Sequential()

# Input layer en eerste hidden layer met Dropout
model_2.add(Dense(128, input_shape=(5,), activation='relu'))
model_2.add(Dropout(0.2))

# Tweede hidden layer
model_2.add(Dense(64, activation='relu'))
model_2.add(Dropout(0.2))

# Derde hidden layer
model_2.add(Dense(32, activation='relu'))
model_2.add(Dropout(0.2))

# Output layer
model_2.add(Dense(1, activation='linear'))

# Compileer het model
model_2.compile(optimizer=Adam(learning_rate=0.001),
                loss='mean_squared_error',
                metrics=['mean_absolute_error'])

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train het model
history = model_2.fit(X_train, y_train,
                      batch_size=32,
                      epochs=1000,
                      validation_split=0.2,
                      callbacks=[early_stop])

# %% [markdown]
# **FCNN-versie_2_1** score: 0,99972

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# # Multimodaal model
